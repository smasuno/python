# %% [markdown]
# # Causal Inference - Practice Notebook

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = 'https://raw.githubusercontent.com/ShubhankarRawat/Heart-Disease-Prediction/master/cleveland.csv'
df = pd.read_csv(url, header=None)
df.columns = ['age', 'sex', 'cp', 'trestbps', 'chol',
              'fbs', 'restecg', 'thalach', 'exang', 
              'oldpeak', 'slope', 'ca', 'thal', 'target']
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal  target
# 0  0.0   6.0       0
# 1  3.0   3.0       2
# 2  2.0   7.0       1
# 3  0.0   3.0       0
# 4  0.0   3.0       0

# %%
import matplotlib.pyplot as plt

dims = (4,4)

f, axes = plt.subplots(dims[0], dims[1], figsize = (25,15))
axis_i, axis_j = 0, 0

for col in df.columns:
    if axis_i * dims[0] + axis_j >= len(df.columns):
        continue

    if col == 'target':
        continue
    
    sns.boxplot(x = df['target'], y = df[col], ax = axes[axis_i, axis_j])
    axis_j += 1

    if axis_j == dims[1]:
        axis_i += 1
        axis_j = 0

# %%
df.restecg.value_counts()
# Out:
# 0    151
# 2    148
# 1      4
# Name: restecg, dtype: int64

# %%
temp = df[df['target'] == 1]
temp.restecg.value_counts()
# Out:
# 2    32
# 0    23
# Name: restecg, dtype: int64

# %% [markdown]
# # A/B Testing
